# %%
import csv
import pandas as pd

with open(r"C:\Users\euiso\OneDrive\바탕 화면\HiLow\옵션\옵션수익.csv", mode= 'w', encoding='cp949') as f:
    writer = csv.writer(f)
    writer.writerow(['년도', '전년자본', '추가투자', '지출', '옵션수익', '이자비용', '세금', '총수익', '익년자본'])

f = pd.read_csv(r"C:\Users\euiso\OneDrive\바탕 화면\HiLow\옵션\옵션수익.csv", encoding='cp949' )

print(f)

df = pd.DataFrame(f)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import csv
#       2 import pandas as pd
# ----> 4 with open(r"C:\Users\euiso\OneDrive\바탕 화면\HiLow\옵션\옵션수익.csv", mode= 'w', encoding='cp949') as f:
#       5     writer = csv.writer(f)
#       6     writer.writerow(['년도', '전년자본', '추가투자', '지출', '옵션수익', '이자비용', '세금', '총수익', '익년자본'])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# ...

# %%
from PIL import Image
import numpy as np

def read_and_preprocess_image(filename, target_size=(224, 224)):
    # 이미지를 읽어옵니다.
    image = Image.open(filename)
    
    # 이미지 크기를 지정된 대상 크기로 조정합니다.
    image = image.resize(target_size)
    
    # 이미지를 NumPy 배열로 변환합니다.
    image_array = np.array(image)
    
    # 이미지 데이터를 0에서 1 사이의 값으로 정규화합니다.
    image_array = image_array / 255.0
    
    return image_array
# Out:
# Empty DataFrame
# Columns: [년도, 전년자본, 추가투자, 지출, 옵션수익, 이자비용, 세금, 총수익, 익년자본]
# Index: []

# %%
# 이미지 로드 및 전처리 함수
def read_and_process_image(filepath, target_size=(224, 224)):
    try:
        image = Image.open(filepath).convert('L')
        # image = image.convert('RGB')  # 모든 이미지를 3채널 RGB로 변환
        image =image.convert('L')    # 모든 이미지를 흑백으로 병환
        image = image.resize(target_size)
        image = np.array(image) / 255.0
        if len(image.shape) == 2:  # grayscale 이미지인 경우 채널 추가
            image = np.stack((image,)*3, axis=-1)
        return image
    except (OSError, ValueError) as e:
        print(f"Error loading image {filepath}: {e}")
        return None

# %%
base_dir = r"C:\Machin_learning\Datasets\cats&dogs\train"
# x_data와 y_data 초기화
x_data = []  # 이미지 데이터
y_data = []  # 성별 데이터 ('man' 또는 'woman')

# 'man' 디렉토리 내의 이미지 파일 처리
cat_dir = os.path.join(base_dir, "cats")
for filename in os.listdir(cat_dir):
    if filename.endswith(".jpg"):
        image_path = os.path.join(cat_dir, filename)
        image = read_and_preprocess_image(image_path)
        x_data.append(image)
        y_data.append('man')

# 'woman' 디렉토리 내의 이미지 파일 처리
dog_dir = os.path.join(base_dir, "dogs")
for filename in os.listdir(dog_dir):
    if filename.endswith(".jpg"):
        image_path = os.path.join(dog_dir, filename)
        image = read_and_preprocess_image(image_path)
        x_data.append(image)
        y_data.append('woman')

# x_data와 y_data를 NumPy 배열로 변환 (이 부분은 필요에 따라 추가)
x_train = np.array(x_data)
y_train = np.array(y_data)

# 이후에 모델 학습 등의 작업을 수행할 수 있습니다.
print(x_train.shape)
print(y_train.shape)
# Out:
# Empty DataFrame
# Columns: [김의수, 김유리, 김지연, 김소연, 김가연]
# Index: []

# %%
# 이미지 화일을 읽어 들이고  그것을 train, test 로 나누어 준다
# x 데이터는 텐서로 만들어 정규화 하고 y 데이터는 범주형으로 만든다

from PIL import Image 
import numpy as np 
import os

def read_preprocessing_image(filename, target_size=(224,224)) :
    image = Image.open(filename)
    image = image.resize(target_size)
    image = np.array(image)
    image = image /255.0

    return image

train_dir = r"D:\Machin_learning\Datasets\man_vs_woman\train"

x_train = []
y_train = []

man_dir = os.path.join(train_dir, 'man')
for filename in os.listdir(man_dir) :
    if filename.endswith('.jpg') :
        image_path = os.path.join(man_dir, filename)
        image = read_preprocessing_image(image_path)
        x_train.append(image)
        y_train.append('1')     #man 이미지는 1 으로 처리한다.

x_train = np.array(x_train)
y_train = np.array(y_train)

test_dir = r'D:\Machin_learning\Datasets\man_vs_woman\test'

x_test = []
y_test = []

woman_dir = os.path.join(test_dir, 'woman')
for filename in os.listdir(woman_dir) :
    if filename.endswith('.jpg') :
        image_path = os.path.join(woman_dir, filename)
        image = read_preprocessing_image(image_path)
        x_test.append(image)
        y_test.append('0')      #  woman 이미지는 0 으로 처리한다.  나중에 mapping 처리도 가능하다.

x_test = np.array(x_test)
y_test = np.array(y_test)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)



# 클래스 레이블 매핑
class_mapping = {'man': 0, 'woman': 1}

# 클래스 레이블을 정수로 변환
y_train = np.array([class_mapping[label] for label in y_train])
y_test = np.array([class_mapping[label] for label in y_test])

# %%
import os
import cv2
import numpy as np

base_dir = r"C:\Machin_learning\Datasets\man_vs_woman"
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

def load_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (224, 224))  # 이미지 크기를 224x224로 변경
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # OpenCV는 BGR 채널 순서를 사용하므로 RGB로 변환
    return image

########  train, test 속의 man, woman 폴더를 
#  for :
#       for 를 이용해서 코딩하면 효율적이다... 

def load_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_dir = os.path.join(directory, label)
        for filename in os.listdir(label_dir):
            if filename.endswith('.jpg'):
                image_path = os.path.join(label_dir, filename)
                image = load_image(image_path)
                images.append(image)
                labels.append(label)
    return images, labels

x_train, y_train = load_images_from_directory(train_dir)
x_test, y_test = load_images_from_directory(test_dir)

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (1791, 224, 224, 3) (1791,) (346, 224, 224, 3) (346,)

# %%
# 이미지를 읽어 들아는 코드.... 

x=[]
y=[]
for i in range(0, final_data.shape[0]) :
    try :
        image = io.imread(final_data.loc[i, 'image_url'])  # 이미지를 일거들이는 위치를 지정해줌...파일의 경로 일수도 있고, url 일 수도 있고
        if(image.shape==(300,300,3)) :
            x.append(image)
            y.append(final_data.loc[i]['please_select_the_gender_of_the_person_in_the_picture'])
    except :   # 블록내의 코드를 실패하면 넘어가고 계속 진행하라는 try except 를 사용함
        
        continue

# %%
# 클래스 레이블 매핑
class_mapping = {'man': 0, 'woman': 1}

# 클래스 레이블을 정수로 변환
y_train = np.array([class_mapping[label] for label in y_train])
y_test = np.array([class_mapping[label] for label in y_test])

print(x_train.class_indices.items())
print(y_train.class_indices.items())

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping, TensorBoard

checkpoint = ModelCheckpoint('./model/model.kras', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
tensorboard = TensorBoard(log_dir='./lods./logs', histogram_freq=1, embeddings_freq=1, write_graph=True, write_images=True)
stopping = EarlyStopping(monitor='val_loss', mode='min', patience=5, verbose=1)
reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

sns.set_style("whitegrid")
plt.figure(figsize=(6,6))
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(pred_ys, axis=-1))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.ylabel("True label")
plt.xlabel('Predict label')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

dt_clf = DecisionTreeClassifier(random_state=0)
dt_clf.fit(x_train, y_train)
dt_pred = dt_clf.predict(x_test)
print('DecisionTreeClassifier accuracy : ', accuracy_score(y_test, dt_pred))

rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(x_train, y_train)
rf_pred = rf_clf.predict(x_test)
print('RandomForestClassifier accuracy : ', accuracy_score(y_test, rf_pred))

lr_clf = LogisticRegression()
lr_clf.fit(x_train, y_train)
lr_pred = lr_clf.predict(x_test)
print('LogisticRegression accuracy : ', accuracy_score(y_test, lr_pred))

# %%
label_map = {
    0 : 'T-shirt/top',
    1 : 'Trouser',
    2 : 'Pullover',
    3 : 'Dress',
    4 : 'Coat',
    5 : 'Sandal',
    6 : 'Shirt',
    7 : 'Sneaker',
    8 : 'Bag',
    9 : 'Ankle boot'
}

plt.figure(figsize=(8, 8))
rows, cols = 4, 4
for i in range(1, rows*cols+1) :
  img = images[i].squeeze()
  label_idx = labels[i].item()
  label = label_map[label_idx]
  plt.subplot(rows, cols, i)
  plt.imshow(img, 'gray')
  plt.title(label)
  plt.axis('off')
plt.show()

# %%
ds_train = ds_train.map(lambda x : (x['input'], [x['output'][key] for key in ['cooling_output', 'pollen_output', 'varroa_output', 'wasps_output']]))
ds_train = ds_train.shuffle(2000).batch(7490)
batch = next(iter(train))
print(batch[0].shape, type(batch[0]), batch[1].shape)

images = batch[0]
print(images.shape)

labels = batch[1]
print(labels.shape)   #리스트는 shape 함수를 사용못한다.

# %%
from tensorflow.keras.applications.vgg16 import VGG16
base_vgg16 = VGG16(input_shape =  (224,224,3), include_top = False, weights = 'imagenet')
base_vgg16.trainable = False
base_vgg16.summary()

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D,UpSampling2D, Dropout, concatenate, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
conv1 = Model(inputs=base_vgg16.input,outputs=base_vgg16.get_layer('block1_conv2').output).output
conv2 = Model(inputs=base_vgg16.input,outputs=base_vgg16.get_layer('block2_conv2').output).output
conv3 = Model(inputs=base_vgg16.input,outputs=base_vgg16.get_layer('block3_conv3').output).output
conv4 = Model(inputs=base_vgg16.input,outputs=base_vgg16.get_layer('block4_conv3').output).output
drop4 = Dropout(0.5)(conv4)
conv5 = Model(inputs=base_vgg16.input,outputs=base_vgg16.get_layer('block5_conv3').output).output
drop5 = Dropout(0.5)(conv5)

up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(UpSampling2D(size =(2,2))(drop5))
merge6 = concatenate([drop4,up6], axis = -1)

conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(merge6)
conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(conv6)
conv6 = BatchNormalization()(conv6)
up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(UpSampling2D(size =(2,2))(conv6))
merge7 = concatenate([conv3,up7], axis = -1)
conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(merge7)
conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(conv7)
conv7 = BatchNormalization()(conv7)
up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(UpSampling2D(size =(2,2))(conv7))
merge8 = concatenate([conv2,up8],axis = -1)
conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(merge8)
conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(conv8)
conv8 = BatchNormalization()(conv8)

up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(UpSampling2D(size =(2,2))(conv8))
merge9 = concatenate([conv1,up9], axis = -1)
conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(merge9)
conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(conv9)
conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer='he_normal')(conv9)
conv9 = BatchNormalization()(conv9)

conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

model = Model(inputs = base_vgg16.input, outputs = conv10)
model.summary()

for layer in model.layers[:18]:
  layer.trainable = False

model.compile(optimizer=Adam(1e-3), 
                   loss='binary_crossentropy', metrics = ['accuracy'])

history = model.fit(x, y,epochs=10,batch_size=1,validation_split=0.1)
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
# ...

# %%
# 이미지 갯수를 증가시키고, 그 이미지의 data augmentation 하기


from tensorflow.keras.preprocessing.image import ImageDataGenerator

gen = ImageDataGenerator(rescale=1./255,
                                  horizontal_flip=True,
                                  vertical_flip=True,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
                                  rotation_range=5,
                                  zoom_range=1.2,
                                  shear_range=0.7,
                                  fill_mode='nearest')



# 보강할 학습데이터 이미지 생성

augment_ratio = 1.5   # 전체 데이터의 150%
augment_size = int(augment_ratio * x_train.shape[0])

print(augment_size)

# 전체 x_train 개수의 150% 비율만큼
randidx = np.random.randint(x_train.shape[0], size=augment_size)

# 임의로 선택된 데이터는 원본데이터를 참조하기 때문에
# 원본데이터에 영향을 줄수 있음. 그래서 copy() 함수를 통해 안전하게 복사본 만듬
x_augmented = x_train[randidx].copy()  
y_augmented = y_train[randidx].copy()

print(x_augmented.shape, y_augmented.shape)

#  이미지 보강 실행
# x_augmented, y_augmented = gen.flow(x_augmented, y_augmented, 
#                                     batch_size=augment_size,
#                                     shuffle=False).next()
# 
# NumpyArrayIterator 객체에는 next() 메서드가 없습니다. 이것은 Python 3에서 제거된 메서드입니다.

# flow() 메서드를 사용하여 이미지를 보강할 때 shuffle=False를 지정한 경우, 
# next() 메서드를 사용하여 데이터를 가져올 필요가 없습니다. 
# flow() 메서드는 데이터를 생성하고 반환하기 때문에 별도로 next() 메서드를 호출할 필요가 없습니다.

# 이미지 보강 실행
flow_iterator = gen.flow(x_augmented, y_augmented, 
                         batch_size=augment_size,
                         shuffle=False)

x_augmented_batch, y_augmented_batch = next(flow_iterator)

print(x_augmented_batch.shape, y_augmented_batch.shape)



# x_train, y_train 에 보강된 데이터 추가

x_train = np.concatenate( (x_train, x_augmented) )
y_train = np.concatenate( (y_train, y_augmented) )

print(x_train.shape, y_train.shape)

# %%
# 토치 데이터를 만들기 위해 . transforms, datasets, DataLoader 를 사용

import torch
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, x_data, y_data):
        self.x_data = x_data
        self.y_data = y_data

    def __len__(self):
        return len(self.x_data)

    def __getitem__(self, idx):
        x = self.x_data[idx]
        y = self.y_data[idx]
        return x, y

# 데이터셋 인스턴스 생성
train_dataset = CustomDataset(x_train, y_train)
test_dataset = CustomDataset(x_test, y_test)

# 데이터로더 생성
batch_size = 64

# Create data loaders.
train_dataset_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataset_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

for X, y in test_dataset_loader:
    print(f"Shape of X [N, C, H, W]: {X.shape}")
    print(f"Shape of y: {y.shape} {y.dtype}")
    break
# 이제 train_loader를 사용하여 모델을 훈련하시면 됩니다!

# %%
#########################################################################################
#####################         간단한 troch  모델            ##############################
#########################################################################################

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(3*300*300, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 2)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)



loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=2e-6)


def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device).float(), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 3 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")




def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device).float(), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")



epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataset_loader, model, loss_fn, optimizer)
    test(test_dataset_loader, model, loss_fn)
print("Done!")

# %%
#####################################################################
#############           복잡한 torch 모델                ##############
#######################################################################

# %%
import torch
import torch.nn as nn

class MyCNNModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)

        self.pooling = nn.MaxPool2d(kernel_size=2, stride=2)

        # Modify the input size of the first fully connected layer
        self.fc1 = nn.Linear(9 * 9 * 256, 128)
        self.fc2 = nn.Linear(128, 2)

        self.dropout25 = nn.Dropout(p=0.25)
        self.dropout50 = nn.Dropout(p=0.5)

    def forward(self, data):
        data = self.conv1(data)
        data = torch.relu(data)
        data = self.conv2(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv3(data)
        data = torch.relu(data)
        data = self.conv4(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv5(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv6(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = self.conv7(data)
        data = torch.relu(data)
        data = self.pooling(data)
        data = self.dropout25(data)

        data = data.view(-1, 9 * 9 * 256)  # Update the view to match the output of the last pooling layer

        data = self.fc1(data)
        data = torch.relu(data)
        data = self.dropout50(data)

        logits = self.fc2(data)

        return logits

net = MyCNNModel()
print(net)

# %%
##########################################################################
#############           transfer  torch 모델                ##############
##########################################################################

# %%
####################################
#   간단한 torch 모델
#####################################

# %%
# Get cpu, gpu or mps device for training.
import torch
device = ('cuda' if torch.cuda.is_available() else 'cpu')

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(3*300*300, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 2)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=2e-6)

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device).float(), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 3 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device).float(), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataset_loader, model, loss_fn, optimizer)
    test(test_dataset_loader, model, loss_fn)
print("Done!")

# %%
#   이미지 분류 모델

alexnet = models.alexnet(weights=models.AlexNet_Weights.DEFAULT)
vgg16 = models.vgg16(weights=models.VGG16_Weights.DEFAULT)
vgg19 = models.vgg19(weights=models.VGG19_Weights.DEFAULT)
resnet18 = models.resnet18(weights=models.ResNet18_Weights.DEFAULT)
resnet50 = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
squeezenet = models.squeezenet1_0(weights=models.SqueezeNet1_0_Weights.DEFAULT)
densenet121 = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
inception_v3 = models.inception_v3(weights=models.Inception_V3_Weights.DEFAULT)
googlenet = models.googlenet(weights=models.GoogLeNet_Weights.DEFAULT)
shufflenet = models.shufflenet_v2_x1_0(weights=models.ShuffleNet_V2_X1_0_Weights.DEFAULT)
mobilenet_v2 = models.mobilenet_v2(weights=models.MobileNet_V2_Weights.DEFAULT)
mobilenet_v3_large = models.mobilenet_v3_large(weights=models.MobileNet_V3_Large_Weights.DEFAULT)
mobilenet_v3_small = models.mobilenet_v3_small(weights=models.MobileNet_V3_Small_Weights.DEFAULT)
efficientnet_b0 = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
regnet_y_400mf = models.regnet_y_400mf(weights=models.RegNet_Y_400MF_Weights.DEFAULT)
wideresnet50_2 = models.wide_resnet50_2(weights=models.Wide_ResNet50_2_Weights.DEFAULT)
mnasnet = models.mnasnet1_0(weights=models.MNASNet1_0_Weights.DEFAULT)


# 객체 검출 모델

faster_rcnn = models.detection.fasterrcnn_resnet50_fpn(weights=models.FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
mask_rcnn = models.detection.maskrcnn_resnet50_fpn(weights=models.MaskRCNN_ResNet50_FPN_Weights.DEFAULT)
retinanet = models.detection.retinanet_resnet50_fpn(weights=models.RetinaNet_ResNet50_FPN_Weights.DEFAULT)
ssd = models.detection.ssd300_vgg16(weights=models.SSD300_VGG16_Weights.DEFAULT)


# 세그멘테이션 모델

fcn = models.segmentation.fcn_resnet50(weights=models.FCN_ResNet50_Weights.DEFAULT)
deeplabv3 = models.segmentation.deeplabv3_resnet50(weights=models.DeepLabV3_ResNet50_Weights.DEFAULT)
lraspp = models.segmentation.lraspp_mobilenet_v3_large(weights=models.LRASPP_MobileNet_V3_Large_Weights.DEFAULT)

# %%
import torch
from torchvision import models

# Pretrained ResNet model
pretrained_model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)

class MyTransferLearningModel(nn.Module):

    def __init__(self, pretrained_model, feature_extractor):
        super().__init__()

        if feature_extractor:
            for param in pretrained_model.parameters():
                param.requires_grad = False

        # Replace the last fully connected layer
        num_features = pretrained_model.fc.in_features
        pretrained_model.fc = nn.Sequential(
            nn.Linear(num_features, 128),
            nn.ReLU(),  # Activation function
            nn.Linear(128, 2)
        )

        self.model = pretrained_model

    def forward(self, data):
        logits = self.model(data)
        return logits

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = MyTransferLearningModel(pretrained_model, feature_extractor=True).to(device)
print(model)

# %%
def load_images_from_directory(directory):
    images = []
    labels = []
    class_names = sorted(os.listdir(directory))

    for label in class_names:
        label_dir = os.path.join(directory, label)
        for filename in os.listdir(label_dir):
            filepath = os.path.join(label_dir, filename)
            try:
                with Image.open(filepath) as img:
                    img.verify()  # Verify that it is an image
                    img = img.resize((224, 224))
                    img = np.array(img) / 255.0
                    if img.ndim == 2:  # If grayscale, convert to RGB
                        img = np.stack((img,)*3, axis=-1)
                    images.append(img)
                    labels.append(label)
            except (IOError, SyntaxError, ValueError) as e:
                print(f"Error loading image {filepath}: {e}")

    return np.array(images), np.array(labels)

x_train, y_train = load_images_from_directory(r"D:\Machin_learning\Datasets\bone break")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load a pre-trained ResNet model
pretrained_resnet = models.resnet18(pretrained=True)

# Modify the last layer for your number of classes (assuming 12 classes here)
num_classes = 5
pretrained_resnet.fc = nn.Linear(pretrained_resnet.fc.in_features, num_classes)

# Transfer the model to the device
pretrained_resnet.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(pretrained_resnet.parameters(), lr=2e-6)

# %%
pip install xception

from xception import Xception  # xception-pytorch 라이브러리

# GPU가 사용 가능하면 cuda로, 아니면 cpu로 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Xception 모델 로드
pretrained_xception = Xception(weights='imagenet')  # 'imagenet' 가중치를 로드

# 마지막 분류층(fc layer) 수정 (여기서는 5개의 클래스로 예시)
num_classes = 5
pretrained_xception.fc = nn.Linear(pretrained_xception.fc.in_features, num_classes)

# 모델을 지정한 장치로 이동
pretrained_xception.to(device)

# 손실 함수 및 최적화 함수 정의
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(pretrained_xception.parameters(), lr=2e-6)

# %%
pip install timn  

import torch
import torch.nn as nn
import torch.optim as optim
import timm  # timm 라이브러리에서 모델을 가져옵니다

# GPU가 사용 가능하면 cuda로, 아니면 cpu로 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ViT 모델 로드 (pretrained=True로 ImageNet 가중치 불러오기)
pretrained_vit = timm.create_model('vit_base_patch16_224', pretrained=True)

# 마지막 분류층(fc layer) 수정 (여기서는 5개의 클래스로 예시)
num_classes = 5
pretrained_vit.head = nn.Linear(pretrained_vit.head.in_features, num_classes)

# 모델을 지정한 장치로 이동
pretrained_vit.to(device)

# 손실 함수 및 최적화 함수 정의
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(pretrained_vit.parameters(), lr=2e-6)

# 모델 학습을 위한 예시 루프
# for epoch in range(num_epochs):
#     for data, labels in dataloader:
#         data, labels = data.to(device), labels.to(device)
#         optimizer.zero_grad()
#         outputs = pretrained_vit(data)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()

# %%
from datetime import datetime

train_loss_list = []
train_accuracy_list = []

val_loss_list = []
val_accuracy_list = []

# Training loop
num_epochs = 25
for epoch in range(num_epochs):
    start_time = datetime.now()
    
    # Training
    model.train()
    train_loss = 0.0
    train_correct = 0
    train_total = 0

    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Calculate training loss
        train_loss += loss.item() * inputs.size(0)

        # Calculate correct predictions
        _, predicted = torch.max(outputs, 1)
        train_correct += torch.sum(predicted == labels).item()
        train_total += labels.size(0)

    # Calculate average training loss and accuracy
    train_avg_loss = train_loss / len(train_dataloader.dataset)
    train_avg_accuracy = 100 * train_correct / train_total

    train_loss_list.append(train_avg_loss)
    train_accuracy_list.append(train_avg_accuracy)

    # Validation
    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Calculate validation loss
            val_loss += loss.item() * inputs.size(0)

            # Calculate correct predictions
            _, predicted = torch.max(outputs, 1)
            val_correct += torch.sum(predicted == labels).item()
            val_total += labels.size(0)

    # Calculate average validation loss and accuracy
    val_avg_loss = val_loss / len(test_dataloader.dataset)
    val_avg_accuracy = 100 * val_correct / val_total

    val_loss_list.append(val_avg_loss)
    val_accuracy_list.append(val_avg_accuracy)

    end_time = datetime.now()
    print(f'Epoch {epoch+1}/{num_epochs}, '
          f'Loss: {train_avg_loss:.4f}, '
          f'Val Loss: {val_avg_loss:.4f}, '
          f'Accuracy: {train_avg_accuracy:.2f}%, '
          f'Val Accuracy: {val_avg_accuracy:.2f}%, '
          f'Time: {end_time - start_time}')
