# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import time
# ----> 2 from selenium import webdriver
#       3 from selenium.webdriver.common.by import By
#
# ModuleNotFoundError: No module named 'selenium'

# %%
url = "https://news.kbs.co.kr/news/pc/category/category.do?ref=pSiteMap#20251004&1"
driver = webdriver.Chrome()
driver.get(url)
# time.sleep(3)

# %%
css_selector = "#contents > div.box.padding-24.field-contents-wrapper.category-main-list > div.box-contents.has-wrap > a:nth-child(1) > div.txt-wrapper > p.title"
title1 = driver.find_element(By.CSS_SELECTOR, css_selector)
print(title1.text)
# Out:
# 미국 연방정부 셧다운

# %%
css_selector = '#contents > div.box.padding-24.field-contents-wrapper.category-main-list > div.box-contents.has-wrap > a:nth-child(1) > div.txt-wrapper > p.news-text'
body1 = driver.find_element(By.CSS_SELECTOR, css_selector)
body1.text
# Out:
# ''

# %%
css_selector = '#contents > div.box.padding-24.field-contents-wrapper.category-main-list > div.box-contents.has-wrap > a:nth-child(1) > div.txt-wrapper > div > span'
day1 = driver.find_element(By.CSS_SELECTOR, css_selector)
day1.text
# Out:
# '2025.10.04 (21:47)'

# %%
css_selector = '#contents > div.box.padding-24.head-line.sub-page-head-line.category-headline'
group_element = driver.find_element(By.CSS_SELECTOR, css_selector)
news_list = group_element.text.split('\n')
print(news_list)
print(len(news_list))
# Out:
# ['가자전쟁 출구 찾나…트럼프 최후 통첩에 하마스 “인질 전원 석방”', '[앵커]장장 2년간 이어져 온 중동 가자지구 전쟁, 종전 기대감이 높아지고 있습니다.지옥을 볼거라는 트럼프 대통령 최후통첩에, 하마스가 인질 석방으로 화답했고, 꿈쩍않던 이스라엘도...', '빛으로 수놓은 가을 남강…진주유등축제 개막', '명절음식의 혈당 상승 속도는? [건강하십니까]', '[단독] 중국, 서해 해양조사 상습방해…5번중 1번 ‘어깃장’', '일본 자민당 새 총재에 ‘여자 아베’ 다카이치…사상 첫 여성 총리 유력']
# 6

# %%
for i in news_list :
    print(i)
# Out:
# 가자전쟁 출구 찾나…트럼프 최후 통첩에 하마스 “인질 전원 석방”
# [앵커]장장 2년간 이어져 온 중동 가자지구 전쟁, 종전 기대감이 높아지고 있습니다.지옥을 볼거라는 트럼프 대통령 최후통첩에, 하마스가 인질 석방으로 화답했고, 꿈쩍않던 이스라엘도...
# 빛으로 수놓은 가을 남강…진주유등축제 개막
# 명절음식의 혈당 상승 속도는? [건강하십니까]
# [단독] 중국, 서해 해양조사 상습방해…5번중 1번 ‘어깃장’
# 일본 자민당 새 총재에 ‘여자 아베’ 다카이치…사상 첫 여성 총리 유력
