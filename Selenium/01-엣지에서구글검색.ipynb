# %%
#  마이크로 소프트 엣지를 이용한 셀레니움 사용법

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

service = Service('msedgedriver.exe')  # 또는 절대경로
driver = webdriver.Edge(service=service)

# %%
url = "https://google.com"
driver.get(url)

# %%
input_box = driver.find_element(By.CSS_SELECTOR, '#APjFqb')
print(input_box)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="15f4d912a0ae3c2935251a76bada2490", element="f.071ED60431AC95331CA805B485C19E91.d.747F385E99DE9C48B69A5D86732D1FF8.e.9")>

# %%
input_box.send_keys('파이썬')
input_box.send_keys(Keys.ENTER)

# %%
#  나는 로못이 아닙니다...를 체크하는 박스가 생긴다....

# %%
#  로봇이 아니라는 체크박스를 체크 하려 하나...실패 한다...

input_box2 = driver.find_element(By.CSS_SELECTOR, '#recaptcha-anchor > div.recaptcha-checkbox-checkmark')
print(input_box2)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[12], line 3
#       1 #  로봇이 아니라는 체크박스를 체크 하려 하나...실패 한다...
# ----> 3 input_box2 = driver.find_element(By.CSS_SELECTOR, '#recaptcha-anchor > div.recaptcha-checkbox-checkmark')
#       4 print(input_box2)
#
# File c:\Users\euiso\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\euiso\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
# ...
