# %%
print('name', 'sum_scores', 'average_score', '\t')

students = [{'name' : 'kim', 'korean' : 94, 'english' : 88, 'math' : 96, 'science' : 99. },
            {'name' : 'park', 'korean' : 93, 'english' : 98, 'math' : 90, 'science' : 93. },
            {'name' : 'lee', 'korean' : 96, 'english' : 78, 'math' : 86, 'science' : 89. },
            {'name' : 'jang', 'korean' : 90, 'english' : 84, 'math' : 89, 'science' : 79. }]

for i in students :
    sum_scores = i['korean'] + i['english'] + i['math'] + i['science']
    average_scores = sum_scores / 4
    print(i['name'], sum_scores, average_scores, sep='\t')
# Out:
# name sum_scores average_score
# kim	377.0	94.25
# park	374.0	93.5
# lee	349.0	87.25
# jang	342.0	85.5

# %%
def creat_student(name, korean, english, math, science) :
    return {'name' : name, 'korean' : korean, 'english': english, 'math' : math, 'science' : science}

def sum_student(student) :
    return student['korean'] + student['english'] + student['math'] + student['science']

def average_student(student) :
    return sum_score / 4

students = [
            creat_student('kim', 94, 88, 96, 99),
            creat_student('park', 93, 98, 90, 93),
            creat_student('lee', 96, 78, 86, 89),
            creat_student('jang', 90, 84, 89, 79),
]

print('name', 'sum_scores', 'average_score', '\t')
for student in students :
    sum_score = sum_student(student)
    average_score = average_student(student)
    print(student['name'], sum_score, average_score, sep='\t')
# Out:
# name sum_scores average_score
# kim	377	94.25
# park	374	93.5
# lee	349	87.25
# jang	342	85.5

# %%
students = [{'name' : 'kim', 'korean' : 94, 'english' : 88, 'math' : 96, 'science' : 99. },
            {'name' : 'park', 'korean' : 93, 'english' : 98, 'math' : 90, 'science' : 93. },
            {'name' : 'lee', 'korean' : 96, 'english' : 78, 'math' : 86, 'science' : 89. },
            {'name' : 'jang', 'korean' : 90, 'english' : 84, 'math' : 89, 'science' : 79. }]

print('name', 'sum_scores', 'average_scores', '\t')

for i in students :
    sum_scores = i['korean'] + i['english'] + i['math'] + i['science']
    average_scores = sum_scores / 4
    print('name', sum_scores, average_scores, sep = '\t')
# Out:
# name sum_scores average_scores
# name	377.0	94.25
# name	374.0	93.5
# name	349.0	87.25
# name	342.0	85.5

# %%
def creat_student(name, korean, english, math, science) :
    return {'name' : name, 'korean' : korean, 'english' : english, 'math' : math, 'science' : science}

def sum_student(student) :
    return student['korean'] + student['english'] + student['math'] + student['science']

def average_student(student) :
    return sum_student(student) / 4


students = [
        creat_student('kim', 94, 88, 96, 99),
        creat_student('lee', 93, 98, 90, 93),
        creat_student('lee', 96, 78, 86, 89),
        creat_student('lee', 90, 84, 89, 79)]

print(students)


print('name', 'sum_scores', 'average_scores')
for i in students :
    sum_score = sum_student(i)
    average_score = average_student(i)
    print('name', sum_score, average_score, sep = '\t')
# Out:
# [{'name': 'kim', 'korean': 94, 'english': 88, 'math': 96, 'science': 99}, {'name': 'lee', 'korean': 93, 'english': 98, 'math': 90, 'science': 93}, {'name': 'lee', 'korean': 96, 'english': 78, 'math': 86, 'science': 89}, {'name': 'lee', 'korean': 90, 'english': 84, 'math': 89, 'science': 79}]
# name sum_scores average_scores
# name	377	94.25
# name	374	93.5
# name	349	87.25
# name	342	85.5
