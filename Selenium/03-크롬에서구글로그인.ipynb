# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import chromedriver_autoinstaller

# %%
driver = webdriver.Chrome()
url = "https://google.com"
driver.get(url)

# %%
action = ActionChains(driver)

# %%
css_selector1 = "#gb > div.gb_z > a"
element1 = driver.find_element(By.CSS_SELECTOR, css_selector1)
element1.click()

# %%
action.send_keys("ramiuss@gmail.com").perform()

# %%
css_selector2 = "#identifierNext > div > button > span"
element2 = driver.find_element(By.CSS_SELECTOR, css_selector2)
element2.click()

# %%
# 앱이 안전하지 않을 수 있다고 하면서 비밀번호를 입력하는 화면으로이동을 하지 않는다..
