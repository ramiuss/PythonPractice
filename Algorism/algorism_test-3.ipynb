# %%
# n! = n * (n - 1) ....
# nPr = n * (n - 1) * (n - 2) ... * (n - r + 1)
# nCr = n! / r! * (n - r) !

def factorial(n) :
    result = 1
    for

# %%
# 문제: 연속된 부분수열의 곱이 K 이하인 경우의 수

# 정수로 이루어진 리스트 nums와 정수 K가 주어집니다.
# 리스트에서 연속된 부분수열(길이 1 이상)의 곱이 K 이하인 경우가 몇 개인지 구하세요.

# 부분수열은 반드시 연속되어야 합니다.

# 각 부분수열의 곱이 K 이하일 때만 카운트합니다.

# nums의 길이는 1 이상 10,000 이하, 각 원소는 1 이상 100 이하의 정수입니다.

# K는 1 이상 10^9 이하의 정수입니다.

# nums = [10, 5, 2, 6]
# K = 100

# %%
nums = [10, 5, 2, 6]
K = 100

count = 0
for i in range(len(nums)) :
    result = 1
    for j in range(i, len(nums)) :
        result *= nums[j]
        if result < K:
            count += 1
            print(f'{nums[i : j + 1]} -> {result} count : {count}')
print(f'총 경우의 수는 {count}')
# Out:
# [10] -> 10 count : 1
# [10, 5] -> 50 count : 2
# [5] -> 5 count : 3
# [5, 2] -> 10 count : 4
# [5, 2, 6] -> 60 count : 5
# [2] -> 2 count : 6
# [2, 6] -> 12 count : 7
# [6] -> 6 count : 8
# 총 경우의 수는 8

# %%
nums = [10, 5, 2, 6]
K = 100

count = 0
for i in range(len(nums)) :
    result = 1
    for j in range(i, len(nums)) :
        result *= nums[j]
        count += 1
        print(f'{nums[i : j + 1]}, -> {result}, count : {count}')

print(f'총 경우의 수는 {count}')
# Out:
# [10], -> 10, count : 1
# [10, 5], -> 50, count : 2
# [10, 5, 2], -> 100, count : 3
# [10, 5, 2, 6], -> 600, count : 4
# [5], -> 5, count : 5
# [5, 2], -> 10, count : 6
# [5, 2, 6], -> 60, count : 7
# [2], -> 2, count : 8
# [2, 6], -> 12, count : 9
# [6], -> 6, count : 10
# 총 경우의 수는 10

# %%
# 문제: "최대 길이의 합이 K 이하인 연속 부분수열 찾기"
# 정수로 이루어진 리스트 nums와 정수 K가 주어집니다.
# 이 리스트에서 연속된 부분수열(서브어레이) 중, 합이 K 이하인 가장 긴 부분수열의 길이를 구하세요.

# 부분수열은 반드시 연속되어야 합니다.

# 부분수열의 합이 K 이하일 때만 유효합니다.

# nums의 길이는 1 이상 10,000 이하, 각 원소는 1 이상 10,000 이하의 정수입니다.

# K는 1 이상 10^9 이하의 정수입니다.

# nums = [1, 2, 3, 4, 5]
# K = 8

# %%
nums = [1, 2, 3, 4, 5]
K = 8
# print(len(nums[1 : 3]))
current_len = 0
for i in range(len(nums)) :
    result = 0 
    for j in range(i, len(nums)) :
        result += nums[j]
        if result <= K :
            if len(nums[i : j + 1]) > current_len :
                current_len = len(nums[i : j + 1])
                print(f'{nums[i : j + 1]} -> result, length : {current_len}')

print(f'가장 긴 부분 수열의 길이는 {current_len}')
# Out:
# [1] -> result, length : 1
# [1, 2] -> result, length : 2
# [1, 2, 3] -> result, length : 3
# 가장 긴 부분 수열의 길이는 3

# %%
# 문제 1: 숫자 카드 2
# N개의 정수 카드가 주어지고, M개의 정수에 대해 각 숫자가 카드에 몇 개 있는지 구하는 프로그램을 작성하세요.

# 입력

# 첫째 줄에 정수 N (1 ≤ N ≤ 500,000)

# 둘째 줄에 N개의 정수 (카드에 적혀있는 숫자, -10,000,000 ≤ 숫자 ≤ 10,000,000)

# 셋째 줄에 정수 M (1 ≤ M ≤ 500,000)

# 넷째 줄에 M개의 정수 (확인할 숫자)

# 출력

# 각 숫자가 카드에 몇 개 있는지 공백으로 구분해 출력

# %%
# 문제 2: 괄호 문자열
# 괄호로 이루어진 문자열이 주어질 때, 올바른 괄호 문자열인지 판별하는 프로그램을 작성하세요.

# 입력

# 첫째 줄에 괄호로만 이루어진 문자열 S (1 ≤ |S| ≤ 100,000)

# 출력

# 올바른 괄호 문자열이면 "YES", 아니면 "NO"를 출력

# %%
# 문제 3: 좌표 정렬하기
# 2차원 평면 위의 점 N개가 주어진다. 좌표를 x좌표 오름차순, x좌표가 같으면 y좌표 오름차순으로 정렬하는 프로그램을 작성하세요.

# 입력

# 첫째 줄에 점의 개수 N (1 ≤ N ≤ 100,000)

# 둘째 줄부터 N개의 줄에 각 점의 x좌표와 y좌표가 주어진다. (-100,000 ≤ x, y ≤ 100,000)

# 출력

# 정렬된 결과를 한 줄에 하나씩 출력

# %%
# 문제 4: 부분합
# N개의 수로 된 수열이 주어졌을 때, 연속된 수들의 부분합 중 그 합이 S 이상이 되는 것 중, 가장 짧은 길이를 구하는 프로그램을 작성하세요.

# 입력

# 첫째 줄에 N, S (1 ≤ N ≤ 100,000, 1 ≤ S ≤ 100,000,000)

# 둘째 줄에 수열의 원소 N개가 주어진다. (1 ≤ 원소 ≤ 10,000)

# 출력

# 조건을 만족하는 부분합의 최소 길이를 출력. 없으면 0을 출력

# %%
# 문제 5: 단어 뒤집기
# 문장이 주어졌을 때, 각 단어를 뒤집어서 출력하는 프로그램을 작성하세요.

# 입력

# 첫째 줄에 문장이 주어진다. (문장 길이 1 ≤ L ≤ 100,000)

# 출력

# 각 단어를 뒤집어서 출력 (단어는 공백으로 구분)
